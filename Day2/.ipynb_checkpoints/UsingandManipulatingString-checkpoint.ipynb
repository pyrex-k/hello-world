# %%
"'Tomorrow is a new day', John said"
# Out:
# "'Tomorrow is a new day', John said"

# %%
name = "john"

# %%
print(f"{name} said that tomorrow is going to be great")
# Out:
# john said that tomorrow is going to be great

# %%
s4 = "Tomorrow will be sunnier than today"

# %%
s4
# Out:
# 'Tomorrow will be sunnier than today'

# %%
s4[0:2] + s4[-2:]
# Out:
# 'Toay'

# %%
s4[0:2].lower() + s4[-2:].upper()
# Out:
# 'toAY'
