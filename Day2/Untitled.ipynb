# %%
if 10 > 50:
    print("Ten is bigger than five")
else: 
    print("It's lower")
print("Today is sunny")
# Out:
# It's lower
# Today is sunny

# %%
if 10 > 50:
    print("Ten is bigger than five")
else: 
    print("It's lower")
print("Today is sunny")

# %%
def sum(a,b):
    """
    This function receives two values that are summed together
    """
    result = a+b # a ia added to b and associated with "result"
    return result # we return "result" variable

# %%
sum(10,20)
# Out:
# 30

# %%
sum("Mike","Elisa")
# Out:
# 'MikeElisa'

# %%
sum("Mike","50")
# Out:
# 'Mike50'

# %%
age = 30

# %%
Age = 20

# %%
age
# Out:
# 30

# %%
Age
# Out:
# 20

# %%
building1 = "Church"

# %%
building1_name = "Church" # snake syntax 
building1Name = "Church" # camel syntax
building1_height = 100

building2_name = "Stadium"
building2_height = 200

building3_name = "Igloo" 
building3_height = 1

# %%
print(building3_name)
# Out:
# Igloo

# %%
student_name = "Maria"

# %%
print(student_name)
print (student_name+student_name)
# Out:
# Maria
# MariaMaria

# %%
type(student_name)
# Out:
# str

# %%
type(building1_height)
# Out:
# int

# %%
dangerous = True

# %%
type(dangerous)
# Out:
# bool

# %%
d = str(dangerous)

# %%
type(d)
# Out:
# str

# %%
d
# Out:
# 'True'

# %%
s = "20"

# %%
int(s)+int(s)
# Out:
# 40

# %%
s+s
# Out:
# '2020'

# %%
a = 10 
b = "Julie" 
c = True
d = 3.5

# %%
e = "data1"
f = "value2"
g = "this_is_a_string"
h = "number_of_students123"

# %%
type(d)
# Out:
# float

# %%
float(a)
# Out:
# 10.0

# %%
type(float(a))
# Out:
# float

# %%
maxdistance = int
Temperature = float
greet_ing = str
isRaining = bool
