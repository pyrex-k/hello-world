# %%
maxdistance = 300
Temperature = 18.1
greet_ing = "Good day" 
isRaining = True

# %%
a = 42 
float(a)
# Out:
# 42.0

# %%
b = 3.14159
int(b)
# Out:
# 3

# %%
c = 99.99
str(c)
float(str(c))
# Out:
# 99.99

# %%
type(isRaining)
# Out:
# bool

# %%
type(greet_ing)
# Out:
# str
