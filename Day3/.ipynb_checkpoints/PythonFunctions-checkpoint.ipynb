# %% [markdown]
# # Working with functions

# %%
def greet(name):
    name = name.upper()
    print(f"hello {name}")

# %%
greet("Alice")
# Out:
# hello ALICE

# %%
employee = "Salim"

greet(employee)
# Out:
# hello SALIM

# %% [markdown]
# # Mastering Python Fucntions

# %%
#ex.1

# %%
def calculate_area(h,w):
    return h*w

# %%
calculate_area(4,5)
# Out:
# 20

# %%
#ex.2

# %%
#ex.3

# %%
my_list = [1,2,3,4,5]

# %%
my_list[-1]
# Out:
# 5

# %%
def first_and_last(l):
    return l[0], l[-1]

first_and_last(my_list)
# Out:
# (1, 5)

# %%
# !pip install numpy

# %%
import numpy

# %%
 # oppure -> !pip install numpy == 2.4.2 # latest version

# %%
dir(numpy) # lists all the funciotns available in  thsi library
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
# ...

# %%
numpy.arange(start=100, stop=200, step=33)
# Out:
# array([100, 133, 166, 199])

# %%
from numpy import arange # i imported a range and i can invoke it without numpy

# %%
numpy.arange(start=100, stop=200, step=33)
# Out:
# array([100, 133, 166, 199])

# %% [markdown]
# # Python modules and libraries

# %%
# ex.1

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
import datetime as dt #DATETIE IS A LIBRARY. the library does not call directly the function, but calls the class fist

# %%
now = dt.datetime.now()
# datetime.now is a static

# %%
now.strftime("%d/%m/%Y %H:%M")
# Out:
# '18/02/2026 09:56'

# %%
# ex.2

# %%
import random

# %%
random.randint(1000, 2000)
# Out:
# 1098

# %% [markdown]
# # Requests library

# %%
# !pip install requests

# %%
import requests

# %%
url = "https://www.google.com"

# %% [raw]
# response = requests.get(url)

# %% [raw]
# response.text

# %% [markdown]
# # OS Library

# %%
import os
os.getcwd() # getcwd -> evidenzia il path e la cartella in cui stai lavorando
# Out:
# '/Users/francescopirovano'

# %% [markdown]
# # Exercise CSV Library

# %%
import csv

with open("my_data.csv") as f:
    reader = csv.reader(f)
    for row in reader: 
        print(row)
# Out:
# ['ID', 'Name', 'Age', 'City ']
# ['1', 'Alice', '34', 'New York']
# ['2', 'Bob', '23', 'Miami']
# ['3', 'Charlie', '40', 'Chicago']
# ['4', 'Diana', '28', 'Houston']
# ['5', 'Evan', '19', 'Phoenix']

# %%
import os

# %%
os.getcwd() # getcwd -> evidenzia il path e la cartella in cui stai lavorando
# Out:
# '/Users/francescopirovano/hello-world/Day3'

# %%
# to improve, use Dict

# %%
import csv

with open("my_data.csv") as f:
    reader = csv.DictReader(f)
    for row in reader: 
        print(row["Name"], row["Age"])
# Out:
# Alice 34
# Bob 23
# Charlie 40
# Diana 28
# Evan 19

# %% [markdown]
# # Tkinter
